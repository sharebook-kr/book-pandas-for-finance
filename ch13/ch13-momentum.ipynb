# %% [markdown]
# ## 13.2 유가증권시장 12개월 모멘텀

# %% [markdown]
# 최근 투자 기간 기준으로 12개월 모멘텀 계산 날짜 구하기

# %%
from pykrx import stock
import FinanceDataReader as fdr

# %%
df = fdr.DataReader(symbol='KS11', start="2019-11")
start = df.loc["2019-11"]
end = df.loc["2020-09"]

# %%
df.loc["2020-11"].head()
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 2020-11-02  2300.16  2276.61  2302.64  2267.95  678500000.0  0.0146
# 2020-11-03  2343.31  2315.81  2344.77  2315.30  887440000.0  0.0188
# 2020-11-04  2357.32  2361.32  2371.14  2339.95  986790000.0  0.0060
# 2020-11-05  2413.79  2373.41  2413.79  2370.85  702040000.0  0.0240
# 2020-11-06  2416.50  2421.79  2431.11  2404.97  825570000.0  0.0011

# %%
start
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 2019-11-01  2100.20  2084.79  2100.42  2081.53  418310000.0  0.0080
# 2019-11-04  2130.24  2111.32  2130.83  2111.32  476260000.0  0.0143
# 2019-11-05  2142.64  2133.66  2143.12  2128.70  400640000.0  0.0058
# 2019-11-06  2144.15  2142.69  2156.23  2138.83  410080000.0  0.0007
# 2019-11-07  2144.29  2141.05  2147.01  2135.45  425660000.0  0.0001
# 2019-11-08  2137.23  2154.18  2155.94  2133.75  574130000.0 -0.0033
# 2019-11-11  2124.09  2139.07  2139.07  2119.07  617270000.0 -0.0061
# 2019-11-12  2140.92  2131.26  2140.94  2121.80  610430000.0  0.0079
# 2019-11-13  2122.45  2132.48  2133.37  2118.67  664360000.0 -0.0086
# 2019-11-14  2139.23  2127.54  2139.23  2121.32  521110000.0  0.0079
# 2019-11-15  2162.18  2137.96  2165.02  2135.26  556250000.0  0.0107
# 2019-11-18  2160.69  2161.89  2165.89  2151.97  489230000.0 -0.0007
# 2019-11-19  2153.24  2151.04  2154.41  2137.01  826880000.0 -0.0034
# 2019-11-20  2125.32  2140.06  2145.97  2123.80  581060000.0 -0.0130
# 2019-11-21  2096.60  2123.65  2125.36  2088.19  579550000.0 -0.0135
# 2019-11-22  2101.96  2098.89  2106.42  2093.99  519850000.0  0.0026
# 2019-11-25  2123.50  2117.14  2130.04  2116.07  397680000.0  0.0102
# 2019-11-26  2121.35  2129.27  2139.64  2120.85  532600000.0 -0.0010
# 2019-11-27  2127.85  2134.47  2136.30  2118.07  367800000.0  0.0031
# 2019-11-28  2118.60  2116.93  2127.75  2116.58  335230000.0 -0.0043
# 2019-11-29  2087.96  2125.53  2125.53  2085.10  433260000.0 -0.0145

# %%
start_date = start.index[0]
end_date = end.index[-1]
print(start_date, end_date)
# Out:
# 2019-11-01 00:00:00 2020-09-29 00:00:00

# %% [markdown]
# 가격 모멘텀 계산 시작일 기준으로 등락률을 계산합니다.

# %%
df1 = stock.get_market_ohlcv_by_ticker("20191101")
df2 = stock.get_market_ohlcv_by_ticker("20200929")
kospi = df1.join(df2, lsuffix="_l", rsuffix="_r")
kospi
# Out:
#           시가_l    고가_l    저가_l    종가_l   거래량_l      거래대금_l  등락률_l      시가_r  \
# 티커
# 095570    4155    4195    4120    4195   39289   162442315   1.08    3225.0
# 068400   11000   11100   10900   11100   88789   973911500   0.45    8430.0
# 006840   31100   31600   31050   31350    8776   274589000   0.16   17400.0
# 027410    5750    5750    5590    5600  331127  1866807440  -2.61    4095.0
# 282330  178500  180000  177500  179500   26325  4710883000   0.84  121500.0
# ...        ...     ...     ...     ...     ...         ...    ...       ...
# 069260   22000   22200   21750   21950   69145  1516793750  -0.68   21500.0
# 000540    3140    3140    3085    3110    7159    22262505  -0.48    2670.0
# 000547   19150   19150   18950   19050      20      380900  -0.52   24500.0
# 000545    4600    4695    4580    4695     669     3113045   1.08   11150.0
# 003280     361     361     352     355  271838    96725636  -1.66       0.0
#
#             고가_r      저가_r      종가_r      거래량_r        거래대금_r  등락률_r
# 티커
# 095570    3290.0    3195.0    3245.0    49795.0  1.619040e+08   0.46
# 068400    8600.0    8380.0    8550.0    98470.0  8.366572e+08   1.79
# 006840   18000.0   17250.0   17550.0    20114.0  3.534758e+08   2.63
# 027410    4100.0    4030.0    4080.0    72477.0  2.950372e+08   0.49
# 282330  124000.0  120000.0  123500.0    71328.0  8.729179e+09   2.49
# ...          ...       ...       ...        ...           ...    ...
# 069260   21500.0   20400.0   20600.0  2564725.0  5.286840e+10  -2.14
# 000540    2840.0    2645.0    2715.0   274386.0  7.525160e+08   1.69
# 000547   25200.0   23750.0   23800.0     8843.0  2.139186e+08  -3.64
# 000545   12700.0   10100.0   10700.0   825125.0  9.490463e+09  -1.38
# 003280       0.0       0.0     258.0        0.0  0.000000e+00   0.00
#
# [910 rows x 14 columns]

# %% [markdown]
# 12개월 등락률(가격 모멘텀, 최근 1개월 제외)을 기준으로 상위 20종목의 종목 코드를 가져와봅시다.

# %%
kospi['모멘텀'] = 100 * (kospi['종가_r'] - kospi['종가_l']) / kospi['종가_l']
kospi = kospi[['종가_l', '종가_r', '모멘텀']]
kospi.sort_values(by='모멘텀', ascending=False)[:20]
# Out:
#          종가_l      종가_r          모멘텀
# 티커
# 019175   6050  166500.0  2652.066116
# 025560    174    3300.0  1796.551724
# 019170   6760  126500.0  1771.301775
# 28513K  20800  166500.0   700.480769
# 005257  18250  138000.0   656.164384
# 011000   4130   29650.0   617.917676
# 037270   1300    8370.0   543.846154
# 007575  16750  106500.0   535.820896
# 010145  56900  356000.0   525.659051
# 285130  47600  296500.0   522.899160
# 030790    850    5180.0   509.411765
# 009835  11550   68200.0   490.476190
# 336260   7860   43100.0   448.346056
# 012170    150     600.0   300.000000
# 000995  36950  142000.0   284.303112
# 002410   1570    6000.0   282.165605
# 033270  19050   72500.0   280.577428
# 002630    432    1625.0   276.157407
# 007570  21750   79200.0   264.137931
# 006125  14650   53000.0   261.774744

# %%
kospi_momentum20 = kospi.sort_values(by='모멘텀', ascending=False)[:20]
kospi_momentum20.rename(columns={"종가_l": "매수가", "종가_r": "매도가"}, inplace=True)
kospi_momentum20
# Out:
#           매수가       매도가          모멘텀
# 티커
# 019175   6050  166500.0  2652.066116
# 025560    174    3300.0  1796.551724
# 019170   6760  126500.0  1771.301775
# 28513K  20800  166500.0   700.480769
# 005257  18250  138000.0   656.164384
# 011000   4130   29650.0   617.917676
# 037270   1300    8370.0   543.846154
# 007575  16750  106500.0   535.820896
# 010145  56900  356000.0   525.659051
# 285130  47600  296500.0   522.899160
# 030790    850    5180.0   509.411765
# 009835  11550   68200.0   490.476190
# 336260   7860   43100.0   448.346056
# 012170    150     600.0   300.000000
# 000995  36950  142000.0   284.303112
# 002410   1570    6000.0   282.165605
# 033270  19050   72500.0   280.577428
# 002630    432    1625.0   276.157407
# 007570  21750   79200.0   264.137931
# 006125  14650   53000.0   261.774744

# %%
df3 = stock.get_market_ohlcv_by_ticker("20201102")
df4 = stock.get_market_ohlcv_by_ticker("20210430")
pct_df = df3.join(df4, lsuffix="_l", rsuffix="_r")
pct_df
# Out:
#           시가_l    고가_l    저가_l    종가_l    거래량_l      거래대금_l  등락률_l      시가_r  \
# 티커
# 095570    3915    3920    3585    3615  1012135  3809998960   1.26    5290.0
# 006840   17100   17600   17100   17400    13765   238146450   1.75   30250.0
# 027410    4015    4080    4015    4050    85711   346880195   0.87    6940.0
# 282330  119000  121000  117500  120000    13771  1642866500   1.69  149500.0
# 138930    5490    5710    5490    5700  1060558  5980071160   3.45    7330.0
# ...        ...     ...     ...     ...      ...         ...    ...       ...
# 069260   22950   23450   22900   23250   109754  2542347150   1.53   21800.0
# 000540    2675    2725    2640    2700    41112   110686885   0.93    4645.0
# 000547   23000   23000   22400   22450     4496   101043200  -2.39   34150.0
# 000545   17100   17550   16200   16800   144608  2439381250   0.00   11350.0
# 003280       0       0       0     258        0           0   0.00       0.0
#
#             고가_r      저가_r      종가_r      거래량_r        거래대금_r  등락률_r
# 티커
# 095570    5560.0    5270.0    5560.0   354540.0  1.944681e+09   4.12
# 006840   31500.0   29900.0   31100.0   185154.0  5.755820e+09   2.81
# 027410    6990.0    6800.0    6910.0   326363.0  2.251853e+09  -0.43
# 282330  154000.0  147500.0  153000.0    63877.0  9.721709e+09   2.34
# 138930    7790.0    7290.0    7670.0  5125163.0  3.907946e+10   4.78
# ...          ...       ...       ...        ...           ...    ...
# 069260   21900.0   21550.0   21750.0   196963.0  4.269144e+09  -0.46
# 000540    4720.0    4440.0    4470.0   435074.0  1.974625e+09  -3.66
# 000547   37500.0   30250.0   32750.0    83155.0  2.820481e+09  13.52
# 000545   12350.0   10600.0   11200.0   105566.0  1.203470e+09   2.75
# 003280       0.0       0.0     258.0        0.0  0.000000e+00   0.00
#
# [915 rows x 14 columns]

# %%
pct_df = pct_df[['종가_l', '종가_r']]
kospi_momentum20_result = kospi_momentum20.join(pct_df)
kospi_momentum20_result
# Out:
#           매수가       매도가          모멘텀    종가_l      종가_r
# 티커
# 019175   6050  166500.0  2652.066116  139000   72900.0
# 025560    174    3300.0  1796.551724    3010   15450.0
# 019170   6760  126500.0  1771.301775  126000   69800.0
# 28513K  20800  166500.0   700.480769  174500  123000.0
# 005257  18250  138000.0   656.164384  159500   89400.0
# 011000   4130   29650.0   617.917676   28650   17400.0
# 037270   1300    8370.0   543.846154    4640    5870.0
# 007575  16750  106500.0   535.820896   82500   37850.0
# 010145  56900  356000.0   525.659051  310000  335000.0
# 285130  47600  296500.0   522.899160  347500  266500.0
# 030790    850    5180.0   509.411765    5770    9100.0
# 009835  11550   68200.0   490.476190   74500   55600.0
# 336260   7860   43100.0   448.346056   41650   45100.0
# 012170    150     600.0   300.000000     600    1105.0
# 000995  36950  142000.0   284.303112  119000  118500.0
# 002410   1570    6000.0   282.165605    4945    4000.0
# 033270  19050   72500.0   280.577428   47750   52400.0
# 002630    432    1625.0   276.157407    1565    1510.0
# 007570  21750   79200.0   264.137931   70200   38250.0
# 006125  14650   53000.0   261.774744   51400   41900.0

# %%
kospi_momentum20_result['수익률'] = (kospi_momentum20_result['종가_r'] / 
                                  kospi_momentum20_result['종가_l'])
kospi_momentum20_result
# Out:
#           매수가       매도가          모멘텀    종가_l      종가_r       수익률
# 티커
# 019175   6050  166500.0  2652.066116  139000   72900.0  0.524460
# 025560    174    3300.0  1796.551724    3010   15450.0  5.132890
# 019170   6760  126500.0  1771.301775  126000   69800.0  0.553968
# 28513K  20800  166500.0   700.480769  174500  123000.0  0.704871
# 005257  18250  138000.0   656.164384  159500   89400.0  0.560502
# 011000   4130   29650.0   617.917676   28650   17400.0  0.607330
# 037270   1300    8370.0   543.846154    4640    5870.0  1.265086
# 007575  16750  106500.0   535.820896   82500   37850.0  0.458788
# 010145  56900  356000.0   525.659051  310000  335000.0  1.080645
# 285130  47600  296500.0   522.899160  347500  266500.0  0.766906
# 030790    850    5180.0   509.411765    5770    9100.0  1.577123
# 009835  11550   68200.0   490.476190   74500   55600.0  0.746309
# 336260   7860   43100.0   448.346056   41650   45100.0  1.082833
# 012170    150     600.0   300.000000     600    1105.0  1.841667
# 000995  36950  142000.0   284.303112  119000  118500.0  0.995798
# 002410   1570    6000.0   282.165605    4945    4000.0  0.808898
# 033270  19050   72500.0   280.577428   47750   52400.0  1.097382
# 002630    432    1625.0   276.157407    1565    1510.0  0.964856
# 007570  21750   79200.0   264.137931   70200   38250.0  0.544872
# 006125  14650   53000.0   261.774744   51400   41900.0  0.815175

# %%
수익률평균 = kospi_momentum20_result['수익률'].fillna(0).mean()
수익률평균
# Out:
# 1.1065180167742072

# %%
mom20_cagr = 수익률평균 ** (1/0.5) - 1    # 6개월
mom20_cagr * 100
# Out:
# 22.438212144592473

# %%
df_ref = fdr.DataReader(
    symbol='KS11', 
    start="2020-11-02",   # 첫번째 거래일
    end="2021-04-30"
)
df_ref
# Out:
#               Close     Open     High      Low        Volume  Change
# Date
# 2020-11-02  2300.16  2276.61  2302.64  2267.95  6.785000e+08  0.0146
# 2020-11-03  2343.31  2315.81  2344.77  2315.30  8.874400e+08  0.0188
# 2020-11-04  2357.32  2361.32  2371.14  2339.95  9.867900e+08  0.0060
# 2020-11-05  2413.79  2373.41  2413.79  2370.85  7.020400e+08  0.0240
# 2020-11-06  2416.50  2421.79  2431.11  2404.97  8.255700e+08  0.0011
# ...             ...      ...      ...      ...           ...     ...
# 2021-04-26  3217.53  3191.34  3217.53  3191.34  1.300000e+09  0.0099
# 2021-04-27  3215.42  3218.30  3223.05  3203.25  1.530000e+09 -0.0007
# 2021-04-28  3181.47  3217.21  3219.69  3176.55  1.410000e+09 -0.0106
# 2021-04-29  3174.07  3184.75  3200.41  3161.06  1.220000e+09 -0.0023
# 2021-04-30  3147.86  3176.43  3179.43  3143.38  1.360000e+09 -0.0083
#
# [124 rows x 6 columns]

# %%
CAGR = ((df_ref['Close'].iloc[-1] / df_ref['Close'].iloc[0]) ** (1/0.5)) -1
CAGR * 100
# Out:
# 87.2900581630561

# %% [markdown]
# ## 13.3 대형주 12개월 모멘텀

# %% [markdown]
# 대형주(시가총액 200위) 기준으로 상대 모멘텀이 큰 종목을 20개 선정하는 전략

# %%
df1 = stock.get_market_ohlcv_by_ticker("20191101", market="ALL")
df2 = stock.get_market_ohlcv_by_ticker("20200929", market="ALL")
all = df1.join(df2, lsuffix="_l", rsuffix="_r")
all
# Out:
#          시가_l   고가_l   저가_l   종가_l   거래량_l      거래대금_l  등락률_l     시가_r  \
# 티커
# 060310   3335   3390   3290   3390  178869   600797865   2.42   2145.0
# 095570   4155   4195   4120   4195   39289   162442315   1.08   3225.0
# 068400  11000  11100  10900  11100   88789   973911500   0.45   8430.0
# 006840  31100  31600  31050  31350    8776   274589000   0.16  17400.0
# 054620   9190   9820   9190   9600  438694  4201716830   4.58   8550.0
# ...       ...    ...    ...    ...     ...         ...    ...      ...
# 000547  19150  19150  18950  19050      20      380900  -0.52  24500.0
# 000545   4600   4695   4580   4695     669     3113045   1.08  11150.0
# 003280    361    361    352    355  271838    96725636  -1.66      0.0
# 037440   4395   4395   4300   4365    8728    37867950   0.34   3665.0
# 238490  23850  24100  22950  23500   63232  1477632650  -1.26  12650.0
#
#            고가_r     저가_r     종가_r     거래량_r        거래대금_r  등락률_r
# 티커
# 060310   2145.0   2085.0   2120.0  116524.0  2.461800e+08   0.95
# 095570   3290.0   3195.0   3245.0   49795.0  1.619040e+08   0.46
# 068400   8600.0   8380.0   8550.0   98470.0  8.366572e+08   1.79
# 006840  18000.0  17250.0  17550.0   20114.0  3.534758e+08   2.63
# 054620   8730.0   8470.0   8590.0  151231.0  1.300975e+09   0.94
# ...         ...      ...      ...       ...           ...    ...
# 000547  25200.0  23750.0  23800.0    8843.0  2.139186e+08  -3.64
# 000545  12700.0  10100.0  10700.0  825125.0  9.490463e+09  -1.38
# 003280      0.0      0.0    258.0       0.0  0.000000e+00   0.00
# 037440   3710.0   3630.0   3690.0    7032.0  2.578092e+07   0.68
# 238490  12900.0  12600.0  12850.0  147805.0  1.886456e+09   2.39
#
# [2442 rows x 14 columns]

# %%
# 기본 필터링
# 우선주 제외 
all2 = all.filter(regex="0$", axis=0).copy()
all2
# Out:
#          시가_l   고가_l   저가_l   종가_l   거래량_l      거래대금_l  등락률_l     시가_r  \
# 티커
# 060310   3335   3390   3290   3390  178869   600797865   2.42   2145.0
# 095570   4155   4195   4120   4195   39289   162442315   1.08   3225.0
# 068400  11000  11100  10900  11100   88789   973911500   0.45   8430.0
# 006840  31100  31600  31050  31350    8776   274589000   0.16  17400.0
# 054620   9190   9820   9190   9600  438694  4201716830   4.58   8550.0
# ...       ...    ...    ...    ...     ...         ...    ...      ...
# 189980   1805   1925   1805   1910  861762  1624718155   5.52   1535.0
# 000540   3140   3140   3085   3110    7159    22262505  -0.48   2670.0
# 003280    361    361    352    355  271838    96725636  -1.66      0.0
# 037440   4395   4395   4300   4365    8728    37867950   0.34   3665.0
# 238490  23850  24100  22950  23500   63232  1477632650  -1.26  12650.0
#
#            고가_r     저가_r     종가_r     거래량_r        거래대금_r  등락률_r
# 티커
# 060310   2145.0   2085.0   2120.0  116524.0  2.461800e+08   0.95
# 095570   3290.0   3195.0   3245.0   49795.0  1.619040e+08   0.46
# 068400   8600.0   8380.0   8550.0   98470.0  8.366572e+08   1.79
# 006840  18000.0  17250.0  17550.0   20114.0  3.534758e+08   2.63
# 054620   8730.0   8470.0   8590.0  151231.0  1.300975e+09   0.94
# ...         ...      ...      ...       ...           ...    ...
# 189980   1560.0   1525.0   1540.0  159233.0  2.442040e+08   0.33
# 000540   2840.0   2645.0   2715.0  274386.0  7.525160e+08   1.69
# 003280      0.0      0.0    258.0       0.0  0.000000e+00   0.00
# 037440   3710.0   3630.0   3690.0    7032.0  2.578092e+07   0.68
# 238490  12900.0  12600.0  12850.0  147805.0  1.886456e+09   2.39
#
# [2323 rows x 14 columns]

# %%
all2['모멘텀'] = 100 * (all2['종가_r'] - all2['종가_l']) / all2['종가_l']
all2 = all2[['모멘텀']]
all2
# Out:
#               모멘텀
# 티커
# 060310 -37.463127
# 095570 -22.646007
# 068400 -22.972973
# 006840 -44.019139
# 054620 -10.520833
# ...           ...
# 189980 -19.371728
# 000540 -12.700965
# 003280 -27.323944
# 037440 -15.463918
# 238490 -45.319149
#
# [2323 rows x 1 columns]

# %%
cap = stock.get_market_cap_by_ticker(date="20200929", market="ALL") 
cap = cap[['시가총액']]
cap
# Out:
#                    시가총액
# 티커
# 005930  347441344410000
# 000660   61152198660000
# 035420   48704096617500
# 051910   46167392322000
# 207940   45653850000000
# ...                 ...
# 224020       2565000000
# 267810       2219945000
# 344860       2046000000
# 225860       2033098468
# 238500       1938416724
#
# [2500 rows x 1 columns]

# %%
all3 = all2.join(other=cap)
all3
# Out:
#               모멘텀          시가총액
# 티커
# 060310 -37.463127  9.498132e+10
# 095570 -22.646007  1.519383e+11
# 068400 -22.972973  3.057919e+11
# 006840 -44.019139  2.324947e+11
# 054620 -10.520833  1.751864e+11
# ...           ...           ...
# 189980 -19.371728  5.685147e+10
# 000540 -12.700965  1.744188e+11
# 003280 -27.323944  3.011700e+10
# 037440 -15.463918  5.137393e+10
# 238490 -45.319149  1.453622e+11
#
# [2323 rows x 2 columns]

# %%
# 대형주 필터링
big = all3.sort_values(by='시가총액', ascending=False)[:200]
big
# Out:
#                모멘텀          시가총액
# 티커
# 005930   13.671875  3.474413e+14
# 000660    1.083032  6.115220e+13
# 035420   77.544910  4.870410e+13
# 051910  111.650485  4.616739e+13
# 207940   74.242424  4.565385e+13
# ...            ...           ...
# 005690  103.954802  1.082259e+12
# 006650   37.603306  1.082250e+12
# 088800  253.970390  1.077194e+12
# 032350   22.222222  1.066845e+12
# 122870  115.613383  1.066451e+12
#
# [200 rows x 2 columns]

# %%
big.sort_values(by='모멘텀', ascending=False)
# Out:
#                 모멘텀          시가총액
# 티커
# 019170  1771.301775  6.702601e+12
# 096530  1113.986014  6.831339e+12
# 011000   617.917676  1.324985e+12
# 285130   522.899160  3.481324e+12
# 336260   448.346056  2.391780e+12
# ...             ...           ...
# 017800   -44.932432  1.589162e+12
# 010950   -49.162562  5.809272e+12
# 145020   -50.177257  2.314834e+12
# 086450   -60.928571  1.215981e+12
# 000100   -70.751708  4.292207e+12
#
# [200 rows x 2 columns]

# %%
big_pct20 = big.sort_values(by='모멘텀', ascending=False)[:20]
big_pct20
# Out:
#                 모멘텀          시가총액
# 티커
# 019170  1771.301775  6.702601e+12
# 096530  1113.986014  6.831339e+12
# 011000   617.917676  1.324985e+12
# 285130   522.899160  3.481324e+12
# 336260   448.346056  2.391780e+12
# 196170   305.168539  5.063347e+12
# 033270   280.577428  1.177750e+12
# 268600   280.149813  1.655893e+12
# 007570   264.137931  1.511585e+12
# 237690   263.775510  1.330173e+12
# 088800   253.970390  1.077194e+12
# 060250   216.397229  1.573540e+12
# 112610   188.500728  1.713014e+12
# 068760   185.283019  4.060854e+12
# 006120   184.632517  1.216519e+12
# 247540   166.796875  2.873404e+12
# 278280   154.179104  1.703000e+12
# 035720   150.515464  3.210086e+13
# 095700   142.444822  3.464387e+12
# 336370   138.670695  1.208295e+12

# %%
df3 = stock.get_market_ohlcv_by_ticker("20201102", market="ALL")
df4 = stock.get_market_ohlcv_by_ticker("20211015", market="ALL")
pct_df = df3.join(df4, lsuffix="_l", rsuffix="_r")
pct_df['수익률'] = pct_df['종가_r'] / pct_df['종가_l']
pct_df = pct_df[['종가_l', '종가_r', '수익률']]
pct_df
# Out:
#          종가_l     종가_r        수익률
# 티커
# 060310   2060   4065.0   1.973301
# 095570   3615   5660.0   1.565698
# 006840  17400  27000.0   1.551724
# 054620   6700  18200.0   2.716418
# 265520  20900  24200.0   1.157895
# ...       ...      ...        ...
# 000547  22450  27950.0   1.244989
# 000545  16800   8570.0   0.510119
# 003280    258   4700.0  18.217054
# 037440   3690   6230.0   1.688347
# 238490  12950   8370.0   0.646332
#
# [2507 rows x 3 columns]

# %%
big_mom_result = big_pct20.join(pct_df)
big_mom_result
# Out:
#                 모멘텀          시가총액    종가_l      종가_r       수익률
# 티커
# 019170  1771.301775  6.702601e+12  126000   62300.0  0.494444
# 096530  1113.986014  6.831339e+12  265400   51900.0  0.195554
# 011000   617.917676  1.324985e+12   28650   28400.0  0.991274
# 285130   522.899160  3.481324e+12  347500  320500.0  0.922302
# 336260   448.346056  2.391780e+12   41650   51000.0  1.224490
# 196170   305.168539  5.063347e+12  158400   76200.0  0.481061
# 033270   280.577428  1.177750e+12   47750   47800.0  1.001047
# 268600   280.149813  1.655893e+12  205000   55900.0  0.272683
# 007570   264.137931  1.511585e+12   70200   30950.0  0.440883
# 237690   263.775510  1.330173e+12   62400   87000.0  1.394231
# 088800   253.970390  1.077194e+12   21150   14650.0  0.692671
# 060250   216.397229  1.573540e+12   68500   55300.0  0.807299
# 112610   188.500728  1.713014e+12  106500   74200.0  0.696714
# 068760   185.283019  4.060854e+12  110700  123900.0  1.119241
# 006120   184.632517  1.216519e+12   64300   49850.0  0.775272
# 247540   166.796875  2.873404e+12  126500  436000.0  3.446640
# 278280   154.179104  1.703000e+12  153700  285200.0  1.855563
# 035720   150.515464  3.210086e+13  334500  122000.0  0.364723
# 095700   142.444822  3.464387e+12  116700   67700.0  0.580120
# 336370   138.670695  1.208295e+12   33050   81900.0  2.478064

# %%
평균수익률 = big_mom_result['수익률'].mean()
big_mom_cagr = (평균수익률 ** 1/1) -1
big_mom_cagr * 100
# Out:
# 1.1713829904023587

# %% [markdown]
# ## 13.4 장기 백테스팅

# %%
import pandas as pd
import datetime
from dateutil.relativedelta import relativedelta

year = 2010
month = 11
period = 6

inv_start = f"{year}-{month}-01"
inv_start = datetime.datetime.strptime(inv_start, "%Y-%m-%d")
inv_end = inv_start + relativedelta(months=period-1)

mom_start = inv_start - relativedelta(months=12)
mom_end = inv_start - relativedelta(months=2)
print(mom_start.strftime("%Y-%m"), mom_end.strftime("%Y-%m"), "=>", 
      inv_start.strftime("%Y-%m"), inv_end.strftime("%Y-%m"))
# Out:
# 2009-11 2010-09 => 2010-11 2011-04

# %%
df = fdr.DataReader(symbol='KS11')
df
# Out:
#               Close     Open     High      Low       Volume  Change
# Date
# 1981-05-01   123.60   123.60   123.60   123.60    3330000.0  0.0098
# 1981-05-02   123.50   123.50   123.50   123.50    2040000.0 -0.0008
# 1981-05-04   120.60   120.60   120.60   120.60    1930000.0 -0.0235
# 1981-05-06   120.70   120.70   120.70   120.70    1690000.0  0.0008
# 1981-05-07   119.30   119.30   119.30   119.30    1480000.0 -0.0116
# ...             ...      ...      ...      ...          ...     ...
# 2021-10-08  2956.30  2977.82  2978.08  2949.01  668950000.0 -0.0011
# 2021-10-12  2916.38  2950.22  2950.94  2901.51  660180000.0 -0.0135
# 2021-10-13  2944.41  2913.34  2953.33  2909.47  752130000.0  0.0096
# 2021-10-14  2988.64  2968.87  2988.97  2962.33  617170000.0  0.0150
# 2021-10-15  3015.06  3012.62  3021.90  2999.33  857800000.0  0.0088
#
# [10806 rows x 6 columns]

# %%
def get_business_day(df, year, month, index=0):
    str_month = f"{year}-{month}"
    return df.loc[str_month].index[index]

# %%
df = fdr.DataReader(symbol='KS11')
get_business_day(df, 2010, 1, 0)
# Out:
# Timestamp('2010-01-04 00:00:00')

# %%
def momentum(df, year=2010, month=11, period=12):
    # 투자 시작일, 종료일
    str_day = f"{year}-{month}-01"
    start = datetime.datetime.strptime(str_day, "%Y-%m-%d")
    end = start + relativedelta(months=period-1)
    inv_start = get_business_day(df, start.year, start.month, 0)   # 첫 번째 거래일의 종가
    inv_end = get_business_day(df, end.year, end.month, -1)
    inv_start = inv_start.strftime("%Y%m%d")
    inv_end = inv_end.strftime("%Y%m%d")
    #print(inv_start, inv_end)
    
    # 모멘텀 계산 시작일, 종료일
    end = start - relativedelta(months=2)     # 역추세 1개월 제외
    start = start - relativedelta(months=period)
    mom_start = get_business_day(df, start.year, start.month, 0)   # 첫 번째 거래일의 종가
    mom_end = get_business_day(df, end.year, end.month, -1)
    mom_start = mom_start.strftime("%Y%m%d")
    mom_end = mom_end.strftime("%Y%m%d")
    print(mom_start, mom_end, " | ", inv_start, inv_end)
    
    # momentum 계산
    df1 = stock.get_market_ohlcv_by_ticker(mom_start)
    df2 = stock.get_market_ohlcv_by_ticker(mom_end)
    mon_df = df1.join(df2, lsuffix="l", rsuffix="r")
    mon_df['등락률'] = (mon_df['종가r'] - mon_df['종가l'])/mon_df['종가l']*100
    
    # 우선주 제외
    mon_df = mon_df.filter(regex="0$", axis=0)
    mon20 = mon_df.sort_values(by="등락률", ascending=False)[:20]
    mon20 = mon20[['등락률']]
    #print(mon20)
    
    # 투자 기간 수익률
    df3 = stock.get_market_ohlcv_by_ticker(inv_start)
    df4 = stock.get_market_ohlcv_by_ticker(inv_end)
    inv_df = df3.join(df4, lsuffix="l", rsuffix="r")
    inv_df['수익률'] = inv_df['종가r'] / inv_df['종가l']    # 수익률 = 매도가 / 매수가
    inv_df = inv_df[['수익률']]
    
    # join
    result_df = mon20.join(inv_df)
    result = result_df['수익률'].fillna(0).mean()
    return year, result

# %%
import time 

data = []
for year in range(2010, 2021):
    ret = momentum(df, year, month=11, period=6)
    data.append(ret)
    time.sleep(1)
# Out:
# 20100503 20100930  |  20101101 20110429
# 20110502 20110930  |  20111101 20120430
# 20120502 20120928  |  20121101 20130430
# 20130502 20130930  |  20131101 20140430
# 20140502 20140930  |  20141103 20150430
# 20150504 20150930  |  20151102 20160429
# 20160502 20160930  |  20161101 20170428
# 20170502 20170929  |  20171101 20180430
# 20180502 20180928  |  20181101 20190430
# 20190502 20190930  |  20191101 20200429
# 20200504 20200929  |  20201102 20210430

# %%
import pandas as pd 

ret_df = pd.DataFrame(data=data, columns=['year', 'yield'])
ret_df.set_index('year', inplace=True)
ret_df
# Out:
#          yield
# year
# 2010  1.069562
# 2011  0.960754
# 2012  1.457754
# 2013  1.076926
# 2014  1.695027
# 2015  0.957410
# 2016  0.905747
# 2017  1.387315
# 2018  1.012361
# 2019  0.764315
# 2020  1.115179

# %%
cum_yield = ret_df['yield'].cumprod()
cum_yield
# Out:
# year
# 2010    1.069562
# 2011    1.027585
# 2012    1.497967
# 2013    1.613200
# 2014    2.734418
# 2015    2.617960
# 2016    2.371210
# 2017    3.289615
# 2018    3.330277
# 2019    2.545379
# 2020    2.838554
# Name: yield, dtype: float64

# %%
CAGR = cum_yield.iloc[-1] ** (1/11) - 1
CAGR * 100
# Out:
# 9.948838383443515

# %%
buy_price = df.loc["2010-11"].iloc[0, 0]
sell_price = df.loc["2021-04"].iloc[-1, 0]
kospi_yield = sell_price / buy_price
kospi_cagr = kospi_yield ** (1/11)-1
kospi_cagr * 100
# Out:
# 4.623147608594103
