# %% [markdown]
# # 신마법공식 데이터

# %%
import pandas as pd 

url = "http://comp.fnguide.com/SVO2/ASP/SVD_Finance.asp?pGB=1&gicode=A005930&cID=&MenuYn=Y&ReportGB=&NewMenuID=103&stkGb=701"
dfs = pd.read_html(url)

# %% [markdown]
# ## Gross Profit

# %%
df = dfs[0]
df
# Out:
#                               IFRS(연결)    2018/12    2019/12    2020/12  \
# 0                                  매출액  2437714.0  2304009.0  2368070.0
# 1                                 매출원가  1323944.0  1472395.0  1444883.0
# 2                                매출총이익  1113770.0   831613.0   923187.0
# 3                판매비와관리비계산에 참여한 계정 펼치기   524903.0   553928.0   563248.0
# 4                                 영업이익   588867.0   277685.0   359939.0
# 5                           영업이익(발표기준)   588867.0   277685.0   359939.0
# 6                   금융수익계산에 참여한 계정 펼치기    99993.0   101616.0   122676.0
# 7                   금융원가계산에 참여한 계정 펼치기    86089.0    82749.0   113181.0
# 8                   기타수익계산에 참여한 계정 펼치기    14850.0    17787.0    13841.0
# 9                   기타비용계산에 참여한 계정 펼치기    11420.0    14147.0    24889.0
# 10  종속기업,공동지배기업및관계기업관련손익계산에 참여한 계정 펼치기     5398.0     4130.0     5065.0
# 11                            세전계속사업이익   611600.0   304322.0   363451.0
# 12                               법인세비용   168151.0    86933.0    99373.0
# 13                              계속영업이익   443449.0   217389.0   264078.0
# 14                              중단영업이익        NaN        NaN        NaN
# 15                               당기순이익   443449.0   217389.0   264078.0
# 16                             지배주주순이익   438909.0   215051.0   260908.0
# 17                            비지배주주순이익     4540.0     2338.0     3170.0
#
#      2021/03      전년동기 전년동기(%)
# 0   653885.0  553252.0    18.2
# 1   415000.0  348067.0    19.2
# 2   238885.0  205185.0    16.4
# 3   145057.0  140711.0     3.1
# 4    93829.0   64473.0    45.5
# 5    93829.0   64473.0    45.5
# 6    22386.0   37914.0   -41.0
# 7    19939.0   34940.0   -42.9
# 8     2997.0    3155.0    -5.0
# 9     3242.0    3641.0   -10.9
# 10    1475.0     606.0   143.3
# 11   97506.0   67569.0    44.3
# 12   26090.0   18719.0    39.4
# 13   71417.0   48849.0    46.2
# 14       NaN       NaN     NaN
# 15   71417.0   48849.0    46.2
# 16   70928.0   48896.0    45.1
# 17     489.0     -47.0    흑자전환

# %%
df2 = df.set_index(df.columns[0])
df2
# Out:
#                                       2018/12    2019/12    2020/12   2021/03  \
# IFRS(연결)
# 매출액                                 2437714.0  2304009.0  2368070.0  653885.0
# 매출원가                                1323944.0  1472395.0  1444883.0  415000.0
# 매출총이익                               1113770.0   831613.0   923187.0  238885.0
# 판매비와관리비계산에 참여한 계정 펼치기                524903.0   553928.0   563248.0  145057.0
# 영업이익                                 588867.0   277685.0   359939.0   93829.0
# 영업이익(발표기준)                           588867.0   277685.0   359939.0   93829.0
# 금융수익계산에 참여한 계정 펼치기                    99993.0   101616.0   122676.0   22386.0
# 금융원가계산에 참여한 계정 펼치기                    86089.0    82749.0   113181.0   19939.0
# 기타수익계산에 참여한 계정 펼치기                    14850.0    17787.0    13841.0    2997.0
# 기타비용계산에 참여한 계정 펼치기                    11420.0    14147.0    24889.0    3242.0
# 종속기업,공동지배기업및관계기업관련손익계산에 참여한 계정 펼치기     5398.0     4130.0     5065.0    1475.0
# 세전계속사업이익                             611600.0   304322.0   363451.0   97506.0
# 법인세비용                                168151.0    86933.0    99373.0   26090.0
# 계속영업이익                               443449.0   217389.0   264078.0   71417.0
# 중단영업이익                                    NaN        NaN        NaN       NaN
# 당기순이익                                443449.0   217389.0   264078.0   71417.0
# 지배주주순이익                              438909.0   215051.0   260908.0   70928.0
# 비지배주주순이익                               4540.0     2338.0     3170.0     489.0
#
#                                         전년동기 전년동기(%)
# IFRS(연결)
# 매출액                                 553252.0    18.2
# 매출원가                                348067.0    19.2
# 매출총이익                               205185.0    16.4
# 판매비와관리비계산에 참여한 계정 펼치기               140711.0     3.1
# 영업이익                                 64473.0    45.5
# 영업이익(발표기준)                           64473.0    45.5
# 금융수익계산에 참여한 계정 펼치기                   37914.0   -41.0
# 금융원가계산에 참여한 계정 펼치기                   34940.0   -42.9
# 기타수익계산에 참여한 계정 펼치기                    3155.0    -5.0
# 기타비용계산에 참여한 계정 펼치기                    3641.0   -10.9
# 종속기업,공동지배기업및관계기업관련손익계산에 참여한 계정 펼치기     606.0   143.3
# 세전계속사업이익                             67569.0    44.3
# 법인세비용                                18719.0    39.4
# 계속영업이익                               48849.0    46.2
# 중단영업이익                                   NaN     NaN
# 당기순이익                                48849.0    46.2
# 지배주주순이익                              48896.0    45.1
# 비지배주주순이익                               -47.0    흑자전환

# %%
df2.filter(regex="^2020").loc["매출총이익"].values[0]
# Out:
# 923187.0

# %% [markdown]
# ## Asset

# %%
df3 = dfs[2]
df4 = df3.set_index(df3.columns[0])
df4
# Out:
#                           2018/12    2019/12    2020/12    2021/03
# IFRS(연결)
# 자산                      3393572.0  3525645.0  3782357.0  3928263.0
# 유동자산계산에 참여한 계정 펼치기      1746974.0  1813853.0  1982156.0  2091554.0
# 비유동자산계산에 참여한 계정 펼치기     1646598.0  1711792.0  1800201.0  1836709.0
# 기타금융업자산                       NaN        NaN        NaN        NaN
# 부채                       916041.0   896841.0  1022877.0  1185577.0
# 유동부채계산에 참여한 계정 펼치기       690815.0   637828.0   756044.0   901095.0
# 비유동부채계산에 참여한 계정 펼치기      225226.0   259013.0   266834.0   284482.0
# 기타금융업부채                       NaN        NaN        NaN        NaN
# 자본                      2477532.0  2628804.0  2759480.0  2742686.0
# 지배기업주주지분계산에 참여한 계정 펼치기  2400690.0  2549155.0  2676703.0  2657673.0
# 비지배주주지분                   76842.0    79649.0    82777.0    85013.0

# %%
df4.filter(regex="^2020").loc["자산"].values[0]
# Out:
# 3782357.0

# %% [markdown]
# ## 시가총액

# %%
url = "http://comp.fnguide.com/SVO2/ASP/SVD_main.asp?pGB=1&gicode=A005930&cID=&MenuYn=Y&ReportGB=&NewMenuID=11&stkGb=&strResearchYN="
dfs = pd.read_html(url)
dfs[0].iloc[4,1]
# Out:
# '4805675'

# %% [markdown]
# ## PBR

# %%
url = "https://comp.fnguide.com/SVO2/ASP/SVD_Main.asp?pGB=1&gicode=A005930"
dfs = pd.read_html(url)

# %%
df5 = dfs[10]
df6 = df5.set_index(df5.columns[0])
df6["Annual"].filter(regex="^2020").loc["PBR"].values[0]
# Out:
# 2.06
